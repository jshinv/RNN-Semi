# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

import glob
import os

# %% [markdown]
# # CSV파일 병합하고 중복제거하기

# %%
input_file = r'datasets/' # csv파일들이 있는 디렉토리 위치
output_file = r'datasets/naver_movie_all.csv' # 병합하고 저장하려는 파일명

# glob함수로 sales_로 시작하는 파일들을 모은다
allFile_list = glob.glob(os.path.join(input_file, 'naver_movie_reviews_*'))

# 읽어 들인 csv파일 내용을 저장할 빈 리스트를 하나 만든다
allData = []

for file in allFile_list:
    df = pd.read_csv(file) # for구문으로 csv파일들을 읽어 들인다
    allData.append(df) # 빈 리스트에 읽어 들인 내용을 추가한다

# concat함수를 이용해서 리스트의 내용을 병합
dataCombine = pd.concat(allData, axis=0, ignore_index=True)

# axis=0은 수직으로 병합함. axis=1은 수평. ignore_index=True는 인데스 값이 기존 순서를 무시하고 순서대로 정렬되도록 한다.
# to_csv함수로 저장한다. 인데스를 빼려면 False로 설정


dataCombine.to_csv(output_file, index=False)
# Out:
# ['datasets/naver_movie_reviews_20200501.csv', 'datasets/naver_movie_reviews_20200430.csv']

# %%
data = pd.read_csv("datasets/naver_movie_all.csv")
data = pd.DataFrame(data, columns=["num", "document", "star", "label"])
data = data.drop(["num"], axis=1)

# data.head()
all_data = len(data)

data
# Out:
#                                                 document star  label
# 0                                                    와우    10      1
# 1                                       아이들과 정말 재밌게봤어요~    10      1
# 2                                                    NaN   10      1
# 3      진부한 스토리가 예상되고 넷플릭스의 수많은 저질 작품들, 또 나오는 크리스 햄스워스...   10      1
# 4         팝콘 먹으러 영화관온거 같음....아.. 맞다.. 푹 자서 내용이 기억이 안나네?     1      0
# ...                                                  ...  ...    ...
# 18525                안타까운 마음. 우리가 얼마나더 그들의 희생을 강요해야할까요.    10      1
# 18526  파수꾼 감독이 만든 영화 맞습니까? 넷플호갱에 팔아서 본전은 건졌으니 다음엔 좋은 ...    2      0
# 18527  영화 배경, 일본만화 실사 같은 암울한 분위기 정말 훌륭해요! 큰화면에 좋은 음향이...    9      1
# 18528  아. 진짜 재미없다. 시간만 버림. 노잼 노감동.. 에휴 뭐가 땅, 불, 바람, 물...    1      0
# 18529    긴장감 있고 재밌어요. 넷플릭스로 개봉해서 집에서 편하게 볼 수 있어서 더 좋아요~     9      1
#
# [18530 rows x 3 columns]

# %%
same_datas = len(data.drop_duplicates("document"))
print('중복 제거수:', same_datas)

data = data.drop_duplicates("document", keep="first")
data = data.reset_index()
data
# Out:
# 중복 제거수: 9237
#       index                                           document star  label
# 0         0                                                와우    10      1
# 1         1                                   아이들과 정말 재밌게봤어요~    10      1
# 2         2                                                NaN   10      1
# 3         3  진부한 스토리가 예상되고 넷플릭스의 수많은 저질 작품들, 또 나오는 크리스 햄스워스...   10      1
# 4         4     팝콘 먹으러 영화관온거 같음....아.. 맞다.. 푹 자서 내용이 기억이 안나네?     1      0
# ...     ...                                                ...  ...    ...
# 9232  18525                안타까운 마음. 우리가 얼마나더 그들의 희생을 강요해야할까요.    10      1
# 9233  18526  파수꾼 감독이 만든 영화 맞습니까? 넷플호갱에 팔아서 본전은 건졌으니 다음엔 좋은 ...    2      0
# 9234  18527  영화 배경, 일본만화 실사 같은 암울한 분위기 정말 훌륭해요! 큰화면에 좋은 음향이...    9      1
# 9235  18528  아. 진짜 재미없다. 시간만 버림. 노잼 노감동.. 에휴 뭐가 땅, 불, 바람, 물...    1      0
# 9236  18529    긴장감 있고 재밌어요. 넷플릭스로 개봉해서 집에서 편하게 볼 수 있어서 더 좋아요~     9      1
#
# [9237 rows x 4 columns]
